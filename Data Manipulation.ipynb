# %% [markdown]
# ## Graded Challenge 2
#
# Nama  : Kevin David Hizkia Simangunsong
#
# Batch : BSD-004
#
# Program ini dibuat untuk memahami penggunaan relational database yang melipulti pengambilan data, cleaning data, data manipulation, dan analisi yang berguna untuk pemodelan model analisa sentimen dengan Objectivitas :
#
# - memahami tentang struktur DDL,DML,TCL,DCL,DQL
#
# - mengolah data sebelum ditransfer ke SQL database dengan Pandas.
#
# - testing hasil data yang sudah dibuat dengan query.

# %% [markdown]
# ## 1. DataData Exploration

# %% [markdown]
# A. Dilangkah awal kita bertugas untuk Load Dataset dari link yang sudah disediakan dan menampilakan data yang sudah kita load tersebut.

# %%
# A. Load file data
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/FTDS-learning-materials/phase-0/main/src/Financials.csv',delimiter=",")
df
# Out:
#               Segment                   Country     Product   Discount Band   \
# 0          Government                    Canada   Carretera            None
# 1          Government                   Germany   Carretera            None
# 2           Midmarket                    France   Carretera            None
# 3           Midmarket                   Germany   Carretera            None
# 4           Midmarket                    Mexico   Carretera            None
# ..                ...                       ...          ...             ...
# 695    Small Business                    France    Amarilla            High
# 696    Small Business                    Mexico    Amarilla            High
# 697        Government                    Mexico     Montana            High
# 698        Government                    Canada       Paseo            High
# 699  Channel Partners  United States of America         VTT            High
#
# ...

# %% [markdown]
# B. Menampilkan informasi summary dataset dengan fungsi info yang menampilakan summary  data column dengan total index 700 dan data type tiap kolom .

# %%
#menampilkan data columns, datatype, total data yg ada.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Segment                700 non-null    object
#  1   Country                700 non-null    object
#  2    Product               700 non-null    object
#  3    Discount Band         700 non-null    object
#  4    Units Sold            700 non-null    object
#  5    Manufacturing Price   700 non-null    object
#  6    Sale Price            700 non-null    object
#  7    Gross Sales           700 non-null    object
#  8    Discounts             700 non-null    object
#  9     Sales                700 non-null    object
#  10   COGS                  700 non-null    object
#  11   Profit                700 non-null    object
#  12  Date                   700 non-null    object
#  13  Month Number           700 non-null    int64
# ...

# %% [markdown]
# C. Berikut adalah list data kolom dari dataset yang sudah diambil yang berisi segment,country,product,etc. kemudian kita akan melakukan penghapusan data kolom yang tidak kita gunakan dan mengambil data yang penting saja.

# %%
#fungsi berikut berguna untuk menghapus spasi yang masih ada di kolom. 
df.columns.str.strip()
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount Band', 'Units Sold',
#        'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
#        'Sales', 'COGS', 'Profit', 'Date', 'Month Number', 'Month Name',
#        'Year'],
#       dtype='object')

# %% [markdown]
# D. Selanjutnya kita akan menampikan list unik dari kolom : segment, country, product, discount band. pertama kita harus rename terlebih dahulu kolom name nya. kemudian hitung total unik data masing - masing kolom yang di minta untuk memastikan berapa banyak unik data nya. setelah itu baru kita tampilkan data unik setiap kolom yang di minta

# %%
# code berikut menggunakan fungsi rename dengan lambda untuk menghapus data yang ada spasi. dan menampikan total unik data.
df.rename(columns=lambda x: x.strip(), inplace=True)
df[['Segment','Country','Product','Discount Band']].nunique()
# Out:
# Segment          5
# Country          5
# Product          6
# Discount Band    4
# dtype: int64

# %% [markdown]
# ## 2. Data Cleaning

# %% [markdown]
# A. Dibagian data cleaning kita akan memanipulasi beberapa data meliputi penggantian nama kolom, penghapusan kolom, dan penambahan kolom.

# %%
# Kolom yang mengandung simbol yang ingin dihapus
columns_to_modify = df.select_dtypes(include='object').columns

# Menghapus simbol '$', ',', dan '-'
df[columns_to_modify] = df[columns_to_modify].replace('[\$,\\-,]', '', regex=True)
df.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount Band', 'Units Sold',
#        'Manufacturing Price', 'Sale Price', 'Gross Sales', 'Discounts',
#        'Sales', 'COGS', 'Profit', 'Date', 'Month Number', 'Month Name',
#        'Year'],
#       dtype='object')

# %%
# ganti nama kolom supaya mempermudah pengecekan data
column_Change = {
    'Discount Band': 'Discount_Band',
    'Units Sold': 'Units_Sold',
    'Manufacturing Price': 'Manufacturing_Price',
    'Sale Price': 'Sale_Price',
    'Gross Sales': 'Gross_Sales',
    'Month Number': 'Month_Number',
    'Month Name': 'Month_Name',
    'Date' : 'Tanggal',
    'Year' : 'Tahun'
}
df.rename(columns=column_Change, inplace=True)
df.columns
# Out:
# Index(['Segment', 'Country', 'Product', 'Discount_Band', 'Units_Sold',
#        'Manufacturing_Price', 'Sale_Price', 'Gross_Sales', 'Discounts',
#        'Sales', 'COGS', 'Profit', 'Tanggal', 'Month_Number', 'Month_Name',
#        'Tahun'],
#       dtype='object')

# %%
#menghapus spasi yang ada di dalam dataset
def replace(n):
    n = n.str.strip()
    return n

HapusSpasi=[]
for n in df.columns.to_list():
    if df[n].dtype==object:
        HapusSpasi.append(n)

df[HapusSpasi] = df[HapusSpasi].apply(replace)
df
# Out:
#               Segment                   Country    Product Discount_Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#     Units_Sold Manufacturing_Price Sale_Price Gross_Sales  Discounts  \
# ...

# %% [markdown]
# B. Penggantian tipe data yang sesuai dengan seharusnya.

# %%
#code berikut berfungsi untuk mengganti data type kolom tertentu. 
columns_to_convert = ['Units_Sold', 'Manufacturing_Price', 'Sale_Price', 'Gross_Sales', 'Discounts', 'Sales', 'COGS']
df[columns_to_convert] = df[columns_to_convert].astype(str).apply(lambda x: x.str.strip()).replace('', '0').astype(float)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Segment              700 non-null    object
#  1   Country              700 non-null    object
#  2   Product              700 non-null    object
#  3   Discount_Band        700 non-null    object
#  4   Units_Sold           700 non-null    float64
#  5   Manufacturing_Price  700 non-null    float64
#  6   Sale_Price           700 non-null    float64
#  7   Gross_Sales          700 non-null    float64
#  8   Discounts            700 non-null    float64
#  9   Sales                700 non-null    float64
#  10  COGS                 700 non-null    float64
#  11  Profit               700 non-null    object
#  12  Tanggal              700 non-null    object
#  13  Month_Number         700 non-null    int64
#  14  Month_Name           700 non-null    object
# ...

# %%
# mengganti data type Date object menjadi datetime
df['Tanggal'] = pd.to_datetime(df['Tanggal'])

# %%
# Cek dan handling missing value dengan imputasi angka nol '0'
data= []
for profit in df.Profit:
    profit = profit.replace(" ","")
    try:
        if "(" in profit:
            negativeValue = float(profit.strip('()'))
            data.append(negativeValue)
        else:
            data.append(float(profit))
    except:
        data.append(float(0))

df.Profit = data
df
# Out:
#               Segment                   Country    Product Discount_Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units_Sold  Manufacturing_Price  Sale_Price  Gross_Sales  Discounts  \
# ...

# %% [markdown]
# ## 3. Data Normalization

# %% [markdown]
# A. Normalisasi data yang sudah diolah sebelumnya sampai dengan 3NF.

# %% [markdown]
# ## 1nf.

# %%
df
# Out:
#               Segment                   Country    Product Discount_Band  \
# 0          Government                    Canada  Carretera          None
# 1          Government                   Germany  Carretera          None
# 2           Midmarket                    France  Carretera          None
# 3           Midmarket                   Germany  Carretera          None
# 4           Midmarket                    Mexico  Carretera          None
# ..                ...                       ...        ...           ...
# 695    Small Business                    France   Amarilla          High
# 696    Small Business                    Mexico   Amarilla          High
# 697        Government                    Mexico    Montana          High
# 698        Government                    Canada      Paseo          High
# 699  Channel Partners  United States of America        VTT          High
#
#      Units_Sold  Manufacturing_Price  Sale_Price  Gross_Sales  Discounts  \
# ...

# %% [markdown]
# ## 2nf

# %%
# code segment_mapping berfungsi sebagai dictionary keys and value 
segment_mapping = {
    'Government': 1,
    'Midmarket': 2,
    'Channel Partners': 3,
    'Enterprise': 4,
    'Small Business': 5
}
# membuat kolom baru 'Segment_ID' dengan numerical values berdasarkan dictionary
df['segment_ID'] = df['Segment'].replace(segment_mapping)

# menampikan values dati segment dan segment_ID 
df[['segment_ID','Country','Product', 'Discount_Band', 'Units_Sold',
    'Manufacturing_Price', 'Sale_Price', 'Gross_Sales', 'Discounts',
    'Sales', 'COGS', 'Profit', 'Tanggal', 'Month_Number', 'Month_Name', 'Tahun',]]
# Out:
#      segment_ID                   Country    Product Discount_Band  \
# 0             1                    Canada  Carretera          None
# 1             1                   Germany  Carretera          None
# 2             2                    France  Carretera          None
# 3             2                   Germany  Carretera          None
# 4             2                    Mexico  Carretera          None
# ..          ...                       ...        ...           ...
# 695           5                    France   Amarilla          High
# 696           5                    Mexico   Amarilla          High
# 697           1                    Mexico    Montana          High
# 698           1                    Canada      Paseo          High
# 699           3  United States of America        VTT          High
#
#      Units_Sold  Manufacturing_Price  Sale_Price  Gross_Sales  Discounts  \
# 0        1618.5                  3.0        20.0      32370.0       0.00
# ...

# %% [markdown]
# ## 3nf

# %%
# membuat kolom baru dengan segment_id dan segment. menggunakan funsgi drop_duplikat
df[['segment_ID','Segment']].drop_duplicates()
# Out:
#     segment_ID           Segment
# 0            1        Government
# 2            2         Midmarket
# 7            3  Channel Partners
# 11           4        Enterprise
# 12           5    Small Business

# %%
# code segment_mapping berfungsi sebagai dictionary keys and value 
country_mapping = {
    'Canada': 1,
    'Germany': 2,
    'France': 3,
    'Mexico': 4,
    'United States of America': 5
}

# membuat kolom baru 'country_ID' dengan numerical values berdasarkan dictionary
df['country_ID'] = df['Country'].replace(country_mapping)

# menampikan values dati country_ID dan Country 
df[['country_ID','Country']].drop_duplicates()
# Out:
#     country_ID                   Country
# 0            1                    Canada
# 1            2                   Germany
# 2            3                    France
# 4            4                    Mexico
# 15           5  United States of America

# %%
# code segment_mapping berfungsi sebagai dictionary keys and value 
product_mapping = {
    'Carretera': 1,
    'Montana': 2,
    'Paseo': 3,
    'Velo': 4,
    'VTT': 5,
    'Amarilla' : 6
}

# membuat kolom baru 'product_ID' dengan numerical values berdasarkan dictionary
df['product_ID'] = df['Product'].replace(product_mapping)

# menampikan values dati product_ID dan product_ID 
df[['product_ID','Product']].drop_duplicates()
# Out:
#     product_ID    Product
# 0            1  Carretera
# 6            2    Montana
# 16           3      Paseo
# 31           4       Velo
# 38           5        VTT
# 45           6   Amarilla

# %%
# code segment_mapping berfungsi sebagai dictionary keys and value 
discount_band = {
    'None': 1,
    'Low': 2,
    'Medium': 3,
    'High': 4
}

# membuat kolom baru 'discountBand_ID' dengan numerical values berdasarkan dictionary
df['discountBand_ID'] = df['Discount_Band'].replace(discount_band)

# menampikan values dati discountBand_ID dan Discount_Band 
df[['discountBand_ID','Discount_Band']].drop_duplicates()
# Out:
#      discountBand_ID Discount_Band
# 0                  1          None
# 53                 2           Low
# 213                3        Medium
# 455                4          High

# %%
#code selected_columns berfungsi memilih kolom yang akan di gunakan di pembuat table
selected_columns = ['segment_ID', 'Segment']
selected_df = df[selected_columns]
selected_df_no_duplicates = selected_df.drop_duplicates()

#code berikut berfungsi untuk membuat table yang di panggil menjadi file csv.
selected_df_no_duplicates.to_csv('Segment.csv', index=False)

# %%
#code selected_columns berfungsi memilih kolom yang akan di gunakan di pembuat table
selected_columns = ['country_ID', 'Country']
selected_df = df[selected_columns]
selected_df_no_duplicates = selected_df.drop_duplicates()

#code berikut berfungsi untuk membuat table yang di panggil menjadi file csv.
selected_df_no_duplicates.to_csv('country.csv', index=False)

# %%
#code selected_columns berfungsi memilih kolom yang akan di gunakan di pembuat table
selected_columns = ['product_ID', 'Product']
selected_df = df[selected_columns]
selected_df_no_duplicates = selected_df.drop_duplicates()

#code berikut berfungsi untuk membuat table yang di panggil menjadi file csv.
selected_df_no_duplicates.to_csv('product.csv', index=False)

# %%
#code selected_columns berfungsi memilih kolom yang akan di gunakan di pembuat table
selected_columns = ['discountBand_ID', 'Discount_Band']
selected_df = df[selected_columns]
selected_df_no_duplicates = selected_df.drop_duplicates()

#code berikut berfungsi untuk membuat table yang di panggil menjadi file csv.
selected_df_no_duplicates.to_csv('DiscountBand.csv', index=False)

# %%
# Display the unique values in the 'Segment' and 'Segment_ID' columns
selected_columns = ['segment_ID','country_ID','product_ID', 'discountBand_ID', 'Units_Sold',
    'Manufacturing_Price', 'Sale_Price', 'Gross_Sales', 'Discounts',
    'Sales', 'COGS', 'Profit', 'Tanggal', 'Month_Number', 'Month_Name', 'Tahun']
selected_df = df[selected_columns]
selected_df_no_duplicates = selected_df.drop_duplicates()

#code selected_columns berfungsi memilih kolom yang akan di gunakan di pembuat table
selected_df_no_duplicates.to_csv('Financial.csv', index=False)

# %% [markdown]
# ## 5. Pengujian Database

# %%
# A. Query mencari total_profit berdasarkan segment. 

# SELECT  financial.segment_id, SUM(financial.profit) AS total_profit
# FROM financial
# WHERE financial.discounts > 0
# GROUP BY financial.segment_id;

# %%
df = pd.read_csv('Hasil_Query1.csv')
df
# Out:
#    segment_id  total_profit
# 0           1   10270950.18
# 1           3    1150321.14
# 2           5    3848268.50
# 3           4     879096.88
# 4           2     563253.09

# %%
# B. Rangkuman statistik yang memuat nilai rata-rata, min, dan max dari Sales masing-masing negara.

# SELECT MIN(financial.sales) as Minimum_Sales,
# 	   MAX(financial.sales) as Maximum_Sales,
# 	   AVG(financial.sales) as Average_sales
# FROM financial
# GROUP BY financial.country_id;

# %%
df = pd.read_csv('Hasil_Query2.csv')
df
# Out:
#    country_id  minimum_sales  maximum_sales  average_sales
# 0           1        1655.08      1038082.5  177768.963500
# 1           3        1763.86       962500.0  173958.373500
# 2           5        1730.54      1159200.0  178784.501286
# 3           4        2508.66       848172.5  149638.229357
# 4           2        1685.60      1017338.0  167895.291571

# %% [markdown]
# ## 6. Conclusion

# %% [markdown]
# from the graded challenge that bootcamp assigned to us, I'm learned how to solve problems and use critical thinking depending on how the question is explained, from the GC there are some objectives that I gained :
#
#     -Explored and loaded the data, identified data issues, and performed necessary cleaning.
#
#     -Normalized data into separate tables and saved to CSV files.
#
#     -Created a relational database with appropriate tables and imported data.
#
#     -Set up users and granted specific access privileges.
#
#     -Tested the database with sample queries and saved them to an SQL file.
#
# the objective above there is still so much to learn and make it better.
